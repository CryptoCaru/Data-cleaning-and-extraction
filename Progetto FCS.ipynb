# %% [markdown]
# <span style="color:green;font-weight:bold;font-style:bold;font-size:30px"> FOUNDATION OF COMPUTER SCIENCE - PROJECT </span>

# %% [markdown]
# Starting from the Google Play Store dataset

# %%
import pandas as pd
import numpy as np

gps = pd.read_csv('C:/Users/loryj/Desktop/UNI/PRIMO SEMESTRE/FOUNDATION OF COMPUTER SCIENCE/PROGETTO/googleplaystore.csv')
gpsur = pd.read_csv('C:/Users/loryj/Desktop/UNI/PRIMO SEMESTRE/FOUNDATION OF COMPUTER SCIENCE/PROGETTO/googleplaystore_user_reviews.csv')

# %%
gps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
gpsur.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
# why deleting row 10472
gps.loc[10472, :]
# Out:
# App               Life Made WI-Fi Touchscreen Photo Frame
# Category                                              1.9
# Rating                                                 19
# Reviews                                              3.0M
# Size                                               1,000+
# Installs                                             Free
# Type                                                    0
# Price                                            Everyone
# Content Rating                                        NaN
# Genres                                  February 11, 2018
# Last Updated                                       1.0.19
# Current Ver                                    4.0 and up
# Android Ver                                           NaN
# Name: 10472, dtype: object

# %% [markdown]
# <span style="color:green;font-weight:bold;font-style:italic;font-size:14px">DATA CLEANING </span>

# %%
gps = gps.drop(gps.index[10472])
gps[gps == 'Varies with device'] = np.nan

gpsur = gpsur.dropna()

gps = gps.reset_index(drop=True)
gpsur = gpsur.reset_index(drop=True)

# %% [markdown]
# <span style="color:green;font-weight:bold;font-size:20px"> EXERCISE 1: Convert the app sizes to a number

# %%
measure = gps['Size']
measure = measure.replace(['[0-9][.]','M','k'],['','1000000','1000'],regex=True)
gps['Size'] = pd.to_numeric(gps['Size'].replace(["M","k"],['',''],regex=True), errors='ignore') # errors to ignore NaN
measure = np.array(measure, dtype=float) # converting to float and not to int because there are NaN
gps['Size'] = gps['Size']*measure

# %% [markdown]
# <span style="color:green;font-weight:bold;font-size:20px"> EXERCISE 2: Convert the number of installs to a number

# %%
gps['Installs'] = gps['Installs'].replace([',','[+]'],['',''],regex=True)
gps['Installs'] = pd.to_numeric(gps['Installs'])

# %%
gps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews          Size  Installs  Type Price Content Rating  \
# 0     159  3.629000e+09     10000  Free     0       Everyone
# 1     967  1.974000e+09    500000  Free     0       Everyone
# 2   87510  6.177000e+08   5000000  Free     0       Everyone
# 3  215644  6.275000e+09  50000000  Free     0           Teen
# 4     967  2.268000e+08    100000  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# ...

# %% [markdown]
# <span style="color:green;font-weight:bold;font-size:20px">EXERCISE 3: Transform “Varies with device” into a missing value

# %%
gps[gps == 'Varies with device'] = np.nan

# %%
gps[gps == "Varies with device"].count()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %% [markdown]
# <span style="color:green;font-weight:bold;font-size:20px"> EXERCISE 4: Convert Current Ver and Android Ver into a dotted number (e.g. 4.0.3 or 4.2)

# %%
# remove if starts or ends with "." or is not 0-9 or "."
gps['Current Ver'] = gps['Current Ver'].replace(["^[\.]","[^\d\.]","[\.]$"], ["", "", ""], regex=True)
gps['Android Ver'] = gps['Android Ver'].replace(["^[\.]","[^\d\.]","[\.]$"], ["", "", ""], regex=True)
gps = gps.replace(r'^\s*$', np.nan, regex=True) # fill empty cells with NaN

# %%
gps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews          Size  Installs  Type Price Content Rating  \
# 0     159  3.629000e+09     10000  Free     0       Everyone
# 1     967  1.974000e+09    500000  Free     0       Everyone
# 2   87510  6.177000e+08   5000000  Free     0       Everyone
# 3  215644  6.275000e+09  50000000  Free     0           Teen
# 4     967  2.268000e+08    100000  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver Android Ver
# ...

# %% [markdown]
# <span style="color:green;font-weight:bold;font-size:20px"> EXERCISE 5: Remove the duplicates

# %%
gps.drop_duplicates(inplace = True)
gps = gps.reset_index(drop=True)

# %%
gps[gps.duplicated()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %% [markdown]
# <span style="color:green;font-weight:bold;font-size:20px"> EXERCISE 6: For each category, compute the number of apps

# %%
Categories_appl = gps.groupby(['Category'])[['App']].count()

# %% [markdown]
# <span style="color:green;font-weight:bold;font-size:20px"> EXERCISE 7: For each category, compute the average rating

# %%
Categories_rating = gps.groupby(['Category'])[['Rating']].mean()

# %% [markdown]
# <span style="color:green;font-weight:bold;font-size:20px"> SUMMARY - A DATAFRAME FOR EXERCISE 6 & 7

# %%
Categories = Categories_appl.join(Categories_rating)
Categories.head()
# Out:
#                      App    Rating
# Category
# ART_AND_DESIGN        65  4.358065
# AUTO_AND_VEHICLES     85  4.190411
# BEAUTY                53  4.278571
# BOOKS_AND_REFERENCE  230  4.347458
# BUSINESS             427  4.102593

# %% [markdown]
# <span style="color:green;font-weight:bold;font-size:20px"> EXERCISE 8: Create two dataframes: one for the genres and one bridging apps and genres. So that, for instance, the app Pixel Draw - Number Art Coloring Book appears twice in the bridging table, once for Art & Design, once for Creativity

# %%
# split genres 
dupl = gps['Genres'].str.split(";", n = 1, expand = True) 

gps_1 = gps.copy()
gps_2 = gps.copy()

gps_1['Genres'] = dupl[0]

# remove null rows
gps_2['Genres'] = dupl[1]
gps_2 = gps_2[gps_2['Genres'].notnull()]

# append in the end of the df the rows with single genre
gps = pd.concat([gps_1,gps_2])
gps = gps.reset_index(drop=True)

# find genres
Genres = gps['Genres'].drop_duplicates()
Genres = pd.DataFrame({'Genres':Genres})
Genres = Genres.reset_index(drop=True)

# table bridging apps and genres
AppGen = gps[['App','Genres']]

# %%
Genres.head()
# Out:
#               Genres
# 0       Art & Design
# 1    Auto & Vehicles
# 2             Beauty
# 3  Books & Reference
# 4           Business

# %%
AppGen.head()
# Out:
#                                                  App        Genres
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  Art & Design
# 1                                Coloring book moana  Art & Design
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  Art & Design
# 3                              Sketch - Draw & Paint  Art & Design
# 4              Pixel Draw - Number Art Coloring Book  Art & Design

# %% [markdown]
# <span style="color:green;font-weight:bold;font-size:20px"> EXERCISE 9: For each genre, create a new column of the original dataframe. The new columns must have boolean values (True if the app has a given genre)

# %%
Header = Genres['Genres']

Genres = pd.DataFrame(index = range(0,len(gps)), columns=Header)

for i in range(0,len(Genres.columns)):
    Genres[Genres.columns[i]]=Genres.columns[i]

for i in range(0,len(Genres.columns)):
    Bool = Genres[Genres.columns[i]] == gps['Genres']
    Genres[Genres.columns[i]] = Bool
    
gps = pd.concat([gps,Genres], axis=1, sort=False)

# %%
gps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews          Size  Installs  Type Price Content Rating        Genres  \
# 0     159  3.629000e+09     10000  Free     0       Everyone  Art & Design
# 1     967  1.974000e+09    500000  Free     0       Everyone  Art & Design
# 2   87510  6.177000e+08   5000000  Free     0       Everyone  Art & Design
# 3  215644  6.275000e+09  50000000  Free     0           Teen  Art & Design
# 4     967  2.268000e+08    100000  Free     0       Everyone  Art & Design
#
# ...

# %%
gps.loc[56]
# Out:
# App                        Gas Prices (Germany only)
# Category                           AUTO_AND_VEHICLES
# Rating                                           4.4
# Reviews                                          805
# Size                                       3.416e+08
# Installs                                       50000
# Type                                            Free
# Price                                              0
# Content Rating                              Everyone
# Genres                               Auto & Vehicles
# Last Updated                           July 29, 2018
# Current Ver                                    2.5.1
# Android Ver                                      4.4
# Art & Design                                   False
# Auto & Vehicles                                 True
# Beauty                                         False
# Books & Reference                              False
# Business                                       False
# ...

# %% [markdown]
# <span style="color:green;font-weight:bold;font-size:20px">EXERCISE 10: For each genre, compute the average rating. What is the genre with highest average?

# %%
avg_rating = gps.groupby(['Genres'], as_index = False)[['Rating']].mean()
avg_rating.head()
# Out:
#                Genres    Rating
# 0              Action  4.280769
# 1  Action & Adventure  4.317600
# 2           Adventure  4.219101
# 3              Arcade  4.305909
# 4        Art & Design  4.349231

# %%
maximum = avg_rating[avg_rating['Rating'] == avg_rating['Rating'].max()]
maximum = maximum.reset_index(drop=True)
print('The genre with maximum average is', maximum.loc[0]['Genres'], 'with AVG', round(maximum.loc[0]['Rating'],2))
# Out:
# The genre with maximum average is Events with AVG 4.44

# %% [markdown]
# <span style="color:green;font-weight:bold;font-size:20px"> EXERCISE 11: For each app, compute the approximate income, obtain as a product of number of installs and price.

# %%
gps['Price'] = pd.to_numeric(gps['Price'].replace('[$]','', regex=True))
gps['Approximate income'] = gps['Price']*gps['Installs']

# %%
gps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews          Size  Installs  Type  Price Content Rating        Genres  \
# 0     159  3.629000e+09     10000  Free    0.0       Everyone  Art & Design
# 1     967  1.974000e+09    500000  Free    0.0       Everyone  Art & Design
# 2   87510  6.177000e+08   5000000  Free    0.0       Everyone  Art & Design
# 3  215644  6.275000e+09  50000000  Free    0.0           Teen  Art & Design
# 4     967  2.268000e+08    100000  Free    0.0       Everyone  Art & Design
#
# ...

# %%
gps[gps['Approximate income'] > 0].head()
# Out:
#                                                App       Category  Rating  \
# 233  TurboScan: scan documents and receipts in PDF       BUSINESS     4.7
# 234                 Tiny Scanner Pro: PDF Doc Scan       BUSINESS     4.8
# 390                             Puffin Browser Pro  COMMUNICATION     4.0
# 429                      Moco+ - Chat, Meet People         DATING     4.2
# 430                                     Calculator         DATING     2.6
#
#     Reviews          Size  Installs  Type  Price Content Rating  \
# 233   11442  5.508000e+08    100000  Paid   4.99       Everyone
# 234   10295  1.524900e+10    100000  Paid   4.99       Everyone
# 390   18247           NaN    100000  Paid   3.99       Everyone
# 429    1545           NaN     10000  Paid   3.99     Mature 17+
# 430      57  1.302000e+08      1000  Paid   6.99       Everyone
#
#             Genres         ...         Weather News & Magazines  \
# 233       Business         ...           False            False
# ...

# %% [markdown]
# <span style="color:green;font-weight:bold;font-size:20px"> EXERCISE 12: For each app, compute its minimum and maximum 'Sentiment_polarity'

# %%
sentiment_polarity_max = gpsur.groupby(['App']).max()
sentiment_polarity_max = sentiment_polarity_max[['Sentiment','Sentiment_Polarity']]

sentiment_polarity_min = gpsur.groupby(['App']).min()
sentiment_polarity_min = sentiment_polarity_min[['Sentiment','Sentiment_Polarity']]

# %%
sentiment_polarity_max.head()
# Out:
#                                  Sentiment  Sentiment_Polarity
# App
# 10 Best Foods for You             Positive            1.000000
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室  Positive            0.910000
# 11st                              Positive            1.000000
# 1800 Contacts - Lens Store        Positive            0.838542
# 1LINE – One Line with One Touch   Positive            1.000000

# %%
sentiment_polarity_min.head()
# Out:
#                                  Sentiment  Sentiment_Polarity
# App
# 10 Best Foods for You             Negative             -0.8000
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室  Negative             -0.1125
# 11st                              Negative             -1.0000
# 1800 Contacts - Lens Store        Negative             -0.3000
# 1LINE – One Line with One Touch   Negative             -0.8250
